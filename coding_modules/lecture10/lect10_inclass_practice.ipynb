# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %% [markdown]
# # In today's practice, we will load a Pandas DataFrame, which contains three explanatory variables, x1, x2, x3, and a predicted variable y. Your task is to create a regression model to use all or a subset of three variables to model y. Find the regression model with lowest AIC or BIC value.

# %%
df = pd.read_csv('lect10_data.csv')

n = df.shape[0] # number of data points
