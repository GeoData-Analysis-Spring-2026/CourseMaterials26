# %% [markdown]
# # Lecture 12 in class practice
#
# # 1. Please perform STL on the air passenger dataset and perform ACF on it. What have you observed?

# %% [markdown]
# # 2. What if we log-transform the air passenger data? What differences did you notice?
