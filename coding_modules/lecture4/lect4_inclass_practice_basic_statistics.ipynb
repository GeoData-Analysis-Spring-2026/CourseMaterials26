# %%
# %matplotlib inline

# %%
import pandas as pd
s = pd.Series([1, 2, 2, 3, 3])
print(s.mode())
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
df = pd.read_csv("Lect4_Data.csv")

# %%
df
# Out:
#            Nrm       nfrm      xpntl       Wbll
# 0    38.296722  54.592243   4.951046   9.523268
# 1    31.328297  25.805080   0.120301  14.501579
# 2    40.175051  55.944995   4.433884   8.605744
# 3    19.921296  67.464134  10.921694   9.020560
# 4     4.279098  -6.557480   0.430349   2.731999
# ..         ...        ...        ...        ...
# 995  14.483638  -7.415161   3.011603   7.193417
# 996   2.541052  40.245887   2.299344   3.048425
# 997  14.274583  15.826342  32.038161   7.370354
# 998  24.584569  14.057804   0.661695  12.937439
# 999  32.623205  13.321258   4.937476   2.875393
#
# [1000 rows x 4 columns]

# %%
# how to select a single column of a dataframe
df['Nrm']
# Out:
# 0      38.296722
# 1      31.328297
# 2      40.175051
# 3      19.921296
# 4       4.279098
#          ...
# 995    14.483638
# 996     2.541052
# 997    14.274583
# 998    24.584569
# 999    32.623205
# Name: Nrm, Length: 1000, dtype: float64

# %%
# how to plot the histogram of a dataframe column
import matplotlib.pyplot as plt
plt.hist(df['Nrm'], bins=30)
# Out:
# (array([ 4.,  1.,  3.,  5.,  6., 10., 17., 17., 30., 40., 45., 55., 92.,
#         99., 75., 82., 77., 83., 59., 62., 41., 25., 25., 22., 10.,  5.,
#          4.,  3.,  0.,  3.]),
#  array([-17.21173393, -14.60806832, -12.0044027 ,  -9.40073709,
#          -6.79707147,  -4.19340586,  -1.58974024,   1.01392537,
#           3.61759099,   6.2212566 ,   8.82492222,  11.42858783,
#          14.03225345,  16.63591906,  19.23958468,  21.84325029,
#          24.44691591,  27.05058152,  29.65424714,  32.25791275,
#          34.86157837,  37.46524398,  40.0689096 ,  42.67257521,
#          45.27624083,  47.87990644,  50.48357206,  53.08723767,
#          55.69090329,  58.2945689 ,  60.89823452]),
#  <BarContainer object of 30 artists>)

# %%
# Create a histogram for each of the four datasets on one plot

# %%
# Make a data frame containing the mean, 25th percentile, median, 
# 75th percentile, and standard deviation of each of the four distributions
import numpy as np
