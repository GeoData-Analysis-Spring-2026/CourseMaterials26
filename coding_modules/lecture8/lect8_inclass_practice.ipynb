# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## In this inclass practice, we still use the annual maximum flow from USGS as an example.

# %% [markdown]
# # Which resampling method we should use, bootstrap, jackknife, or permutation?
#
# ### 1. If we would like to conduct a hypothesis testing, check whether the mean annual peak flow before 1980 (including 1980) is lower than the mean annual peak flow after 1980.

# %% [markdown]
# ### 2. Which resampling method should I use if I would like to know the uncertainty for the mean annual peak flow from 1940 to 2022?
