# %%
# %matplotlib inline

# %% [markdown]
# # Inclass Practice for Lecture 9
#
# Let's practice linear regression using the lecture 9 practice dataset. It contains three columns, including three columns of data, age, experience, and income, respectively.

# %%
import pandas as pd
df = pd.read_csv('lecture9_practice_data.csv')

# %% [markdown]
# # Practice #1: Can you please create a linear regression model between age and income? Please report the Rsquared value.

# %%
# Insert your code here

# %% [markdown]
# # Practice #2: Can you create a multilinear regression to use both age and experience to estimate income? Can you perform a Type I ANOVA analysis and interpret the results?

# %%
# Insert your code here
